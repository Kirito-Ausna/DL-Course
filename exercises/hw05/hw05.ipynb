# %% [markdown]
# ## Homework Assignment 5 - Multilayer Perceptrons (MLP)
#
# We introduced some linear models to do some simple regression and classification tasks.
# If our labels truly were related to the input data by a simple affine transformation,
# then this approach would be sufficient.
# However, linearity (in affine transformations) is a *strong* assumption.
#
# Please implement the following functions and form a simple MLP!

# %% [markdown]
# ## Hidden Layers
# ### Limitations of Linear Models
#
# For example, linearity implies the *weaker* assumption of *monotonicity*, i.e.,
# that any increase in our feature must
# either always cause an increase in our model's output
# (if the corresponding weight is positive),
# or always cause a decrease in our model's output
# (if the corresponding weight is negative).
# Sometimes that makes sense.
# For example, if we were trying to predict
# whether an individual will repay a loan,
# we might reasonably assume that all other things being equal,
# an applicant with a higher income
# would always be more likely to repay
# than one with a lower income.
# While monotonic, this relationship likely
# is not linearly associated with the probability of
# repayment. An increase in income from \$0 to \$50,000
# likely corresponds to a bigger increase
# in likelihood of repayment
# than an increase from \$1 million to \$1.05 million.
# One way to handle this might be to post-process our outcome
# such that linearity becomes more plausible,
# by using the logistic map (and thus the logarithm of the probability of outcome).
#
# Note that we can easily come up with examples
# that violate monotonicity.
# Say for example that we want to predict health as a function
# of body temperature.
# For individuals with a body temperature
# above 37°C (98.6°F),
# higher temperatures indicate greater risk.
# However, for individuals with body temperatures
# below 37°C, lower temperatures indicate greater risk!
# Again, we might resolve the problem
# with some clever preprocessing, such as using the distance from 37°C
# as a feature.
#
# But what about classifying images of cats and dogs?
# Should increasing the intensity
# of the pixel at location (13, 17)
# always increase (or always decrease)
# the likelihood that the image depicts a dog?
# Reliance on a linear model corresponds to the implicit
# assumption that the only requirement
# for differentiating cats vs. dogs is to assess
# the brightness of individual pixels.
# This approach is doomed to fail in a world
# where inverting an image preserves the category.
#
# And yet despite the apparent absurdity of linearity here,
# as compared with our previous examples,
# it is less obvious that we could address the problem
# with a simple preprocessing fix.
# That is, because the significance of any pixel
# depends in complex ways on its context
# (the values of the surrounding pixels).
# While there might exist a representation of our data
# that would take into account
# the relevant interactions among our features,
# on top of which a linear model would be suitable,
# we simply do not know how to calculate it by hand.
# With deep neural networks, we used observational data
# to jointly learn both a representation via hidden layers
# and a linear predictor that acts upon that representation.
#
# We can overcome the limitations of linear models
# by incorporating one or more hidden layers.
# The easiest way to do this is to stack
# many fully connected layers on top of each other.
# Each layer feeds into the layer above it,
# until we generate outputs.
# We can think of the first $L-1$ layers
# as our representation and the final layer
# as our linear predictor.
# This architecture is commonly called
# a *multilayer perceptron*,
# often abbreviated as *MLP*, as shown below.
#
# ![An MLP with a hidden layer of 5 hidden units. ](./imgs/mlp.svg)
#
# This MLP has 4 inputs, 3 outputs,
# and its hidden layer contains 5 hidden units.
# Since the input layer does not involve any calculations,
# producing outputs with this network
# requires implementing the computations
# for both the hidden and output layers;
# thus, the number of layers in this MLP is 2.
# Note that both layers are fully connected.
# Every input influences every neuron in the hidden layer,
# and each of these in turn influences
# every neuron in the output layer. Alas, we are not quite
# done yet.

# %%
# import packages
import torch
import torch.nn as nn
import numpy as np
import torchvision.datasets as dataset
from torch.utils.data import DataLoader
from torchvision import transforms

# %% [markdown]
# ### ReLU Function
#
# The most popular choice,
# due to both simplicity of implementation and
# its good performance on a variety of predictive tasks,
# is the *rectified linear unit* (*ReLU*).
# [**ReLU provides a very simple nonlinear transformation**].
# Given an element $x$, the function is defined
# as the maximum of that element and $0$:
#
# $$\operatorname{ReLU}(x) = \max(x, 0).$$
#
# Informally, the ReLU function retains only positive
# elements and discards all negative elements
# by setting the corresponding activations to 0.
# To gain some intuition, we can plot the function.
# As you can see, the activation function is piecewise linear.

# %%
# Tips: implement ReLU (Rectified Linear Unit) activation function
def relu(x):
    # ReLU Activation Function
    return torch.max(x, torch.zeros_like(x))

# %% [markdown]
# ### Sigmoid Function
#
# [**The *sigmoid function* transforms its inputs**],
# for which values lie in the domain $\mathbb{R}$,
# (**to outputs that lie on the interval (0, 1).**)
# For that reason, the sigmoid is
# often called a *squashing function*:
# it squashes any input in the range (-inf, inf)
# to some value in the range (0, 1):
#
# $$\operatorname{sigmoid}(x) = \frac{1}{1 + \exp(-x)}.$$
#
# In the earliest neural networks, scientists
# were interested in modeling biological neurons
# which either *fire* or *do not fire*.
# Thus the pioneers of this field,
# going all the way back to McCulloch and Pitts,
# the inventors of the artificial neuron,
# focused on thresholding units in 1943.
# A thresholding activation takes value 0
# when its input is below some threshold
# and value 1 when the input exceeds the threshold.
#
# When attention shifted to gradient based learning,
# the sigmoid function was a natural choice
# because it is a smooth, differentiable
# approximation to a thresholding unit.
# Sigmoids are still widely used as
# activation functions on the output units,
# when we want to interpret the outputs as probabilities
# for binary classification problems: you can think of the sigmoid as a special case of the softmax.
# However, the sigmoid has mostly been replaced
# by the simpler and more easily trainable ReLU
# for most use in hidden layers. Much of this has to do
# with the fact that the sigmoid poses challenges for optimization
# since its gradient vanishes for large positive *and* negative arguments.
# This can lead to plateaus that are difficult to escape from.
#
# Below, please implement a Sigmoid function:

# %%
# Tips: pls implement Sigmoid function
def sigmoid(x):
  # Sigmoid Activation Function
  return 1 / (1 + torch.exp(-x))

# %% [markdown]
# ### Tanh Function
#
# Like the sigmoid function, [**the tanh (hyperbolic tangent)
# function also squashes its inputs**],
# transforming them into elements on the interval (**between -1 and 1**):
#
# $$\operatorname{tanh}(x) = \frac{1 - \exp(-2x)}{1 + \exp(-2x)}.$$
#
# We plot the tanh function below. Note that as input nears 0, the tanh function approaches a linear transformation. Although the shape of the function is similar to that of the sigmoid function, the tanh function exhibits point symmetry about the origin of the coordinate system.

# %%
# Tips: pls implement Sigmoid function
def tanh(x):
    # Tanh Activation Function
    return (torch.exp(x) - torch.exp(-x)) / (torch.exp(x) + torch.exp(-x))

# %% [markdown]
# ## Implementation from Scratch
#
# Let's begin again by implementing a MLP from scratch.
#
# ### Initializing Model Parameters
#
# We will use iris dataset from sklearn.
# To begin, we will [**implement an MLP
# with one hidden layer and 256 hidden units.**]
# Both the number of layers and their width are adjustable
# (they are considered hyperparameters).
# Typically, we choose the layer widths to be divisible by larger powers of 2.
# This is computationally efficient due to the way
# memory is allocated and addressed in hardware.

# %%
class MLP(nn.Module):
    def __init__(self, num_outputs, num_hiddens):
        super().__init__()

# Tips: try to use nn.Sequential to implement two layer MLP with ReLU as activation function
        self.model = nn.Sequential(
            nn.Linear(4, num_hiddens),
            nn.Linear(num_hiddens, num_outputs),
            nn.ReLU(),
        )

    # forward function processes data througth model and return results
    def forward(self, x):
        # to do
        return self.model(x)

# %% [markdown]
# Previously, we defined `forward` methods for models to transform input using the model parameters.
# These operations are essentially a pipeline:
# you take an input and
# apply a transformation (e.g.,
# matrix multiplication with weights followed by bias addition),
# then repetitively use the output of the current transformation as
# input to the next transformation.
# However, you may have noticed that
# no `forward` method is defined here.
# In fact, `MLP` inherits the `forward` method from the `Module` class to
# simply invoke `self.net(X)` (`X` is input),
# which is now defined as a sequence of transformations
# via the `Sequential` class.
# The `Sequential` class abstracts the forward process
# enabling us to focus on the transformations.
# We will further discuss how the `Sequential` class works in :numref.
#
#
# ### Training
#
# [**The training loop**] is exactly the same
# as when we implemented softmax regression.
# This modularity enables us to separate
# matters concerning the model architecture
# from orthogonal considerations.
#
# ### Prepare Data

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.autograd import Variable

iris = load_iris()
X = iris['data']
y = iris['target']
names = iris['target_names']
feature_names = iris['feature_names']

# Scale data to have mean 0 and variance 1 
# which is importance for convergence of the neural network
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data set into training and testing
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=2)

# Prepare for training
X_train = Variable(torch.from_numpy(X_train)).float()
y_train = Variable(torch.from_numpy(y_train)).long()
X_test  = Variable(torch.from_numpy(X_test)).float()
y_test  = Variable(torch.from_numpy(y_test)).long()

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([120, 4]),
#  torch.Size([30, 4]),
#  torch.Size([120]),
#  torch.Size([30]))

# %% [markdown]
# ### Visualize the Data

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax1.plot(X_plot[:, 0], X_plot[:, 1], 
             linestyle='none', 
             marker='o', 
             label=target_name)
ax1.set_xlabel(feature_names[0])
ax1.set_ylabel(feature_names[1])
ax1.axis('equal')
ax1.legend()

for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax2.plot(X_plot[:, 2], X_plot[:, 3], 
             linestyle='none', 
             marker='o', 
             label=target_name)
ax2.set_xlabel(feature_names[2])
ax2.set_ylabel(feature_names[3])
ax2.axis('equal')
ax2.legend()

# %%
# Set fixed random number seed and hyperparameters
torch.manual_seed(2023)
learning_rate = 1e-3
batch_size = 128
epochs = 100

# Initialize the MLP
mlp = MLP(num_hiddens=1024, num_outputs=10)

# Define the loss function and optimizer
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(mlp.parameters(), lr=learning_rate) 

# Run the training loop
loss_list, acc_list = [], []
for epoch in range(0, epochs): # 5 epochs at maximum
    # Print epoch
    print(f'Starting epoch {epoch+1}')

    # Zero the gradients
    optimizer.zero_grad()
    
    # Perform forward pass
    outputs = mlp(X_train)
    
    # Compute loss
    loss = loss_function(outputs, y_train)
    
    # Perform backward pass
    loss.backward()
    
    # Perform optimization
    optimizer.step()
        
    # Print statistics
    loss_list.append(loss.item())
    acc_list.append(torch.sum(torch.argmax(outputs, axis=1) == y_train) / len(y_train))

    print('Training loss: %.3f, Training accuracy: %.3f' %
        (loss_list[epoch], acc_list[epoch] * 100))

    # test
    current_loss = 0.0
    current_acc = 0.0
    mlp.eval()
    with torch.no_grad():

        outputs = mlp(X_test)

        current_loss += loss.item()
        current_acc += torch.sum(torch.argmax(outputs, axis=1) == y_test) / len(y_test)


        print('Test loss: %.3f, Test accuracy: %.3f' %
            (current_loss, current_acc * 100))

    # Process is complete.
    print('Training process has finished.')
# Out:
# Starting epoch 1
# Training loss: 2.347, Training accuracy: 0.000
# Test loss: 2.347, Test accuracy: 0.000
# Training process has finished.
# Starting epoch 2
# Training loss: 2.295, Training accuracy: 0.000
# Test loss: 2.295, Test accuracy: 20.000
# Training process has finished.
# Starting epoch 3
# Training loss: 2.229, Training accuracy: 8.333
# Test loss: 2.229, Test accuracy: 46.667
# Training process has finished.
# Starting epoch 4
# Training loss: 2.159, Training accuracy: 31.667
# Test loss: 2.159, Test accuracy: 63.333
# Training process has finished.
# Starting epoch 5
# Training loss: 2.090, Training accuracy: 52.500
# Test loss: 2.090, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 6
# Training loss: 2.024, Training accuracy: 63.333
# Test loss: 2.024, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 7
# Training loss: 1.961, Training accuracy: 63.333
# Test loss: 1.961, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 8
# Training loss: 1.902, Training accuracy: 63.333
# Test loss: 1.902, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 9
# Training loss: 1.845, Training accuracy: 64.167
# Test loss: 1.845, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 10
# Training loss: 1.792, Training accuracy: 64.167
# Test loss: 1.792, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 11
# Training loss: 1.741, Training accuracy: 64.167
# Test loss: 1.741, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 12
# Training loss: 1.694, Training accuracy: 64.167
# Test loss: 1.694, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 13
# Training loss: 1.649, Training accuracy: 65.000
# Test loss: 1.649, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 14
# Training loss: 1.608, Training accuracy: 65.000
# Test loss: 1.608, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 15
# Training loss: 1.569, Training accuracy: 65.000
# Test loss: 1.569, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 16
# Training loss: 1.533, Training accuracy: 65.000
# Test loss: 1.533, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 17
# Training loss: 1.500, Training accuracy: 65.000
# Test loss: 1.500, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 18
# Training loss: 1.468, Training accuracy: 65.000
# Test loss: 1.468, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 19
# Training loss: 1.439, Training accuracy: 65.000
# Test loss: 1.439, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 20
# Training loss: 1.412, Training accuracy: 65.000
# Test loss: 1.412, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 21
# Training loss: 1.386, Training accuracy: 65.000
# Test loss: 1.386, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 22
# Training loss: 1.363, Training accuracy: 65.000
# Test loss: 1.363, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 23
# Training loss: 1.340, Training accuracy: 65.000
# Test loss: 1.340, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 24
# Training loss: 1.319, Training accuracy: 65.000
# Test loss: 1.319, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 25
# Training loss: 1.299, Training accuracy: 65.000
# Test loss: 1.299, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 26
# Training loss: 1.280, Training accuracy: 65.000
# Test loss: 1.280, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 27
# Training loss: 1.262, Training accuracy: 65.000
# Test loss: 1.262, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 28
# Training loss: 1.245, Training accuracy: 65.000
# Test loss: 1.245, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 29
# Training loss: 1.228, Training accuracy: 65.000
# Test loss: 1.228, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 30
# Training loss: 1.212, Training accuracy: 65.000
# Test loss: 1.212, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 31
# Training loss: 1.195, Training accuracy: 65.000
# Test loss: 1.195, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 32
# Training loss: 1.179, Training accuracy: 65.000
# Test loss: 1.179, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 33
# Training loss: 1.163, Training accuracy: 65.000
# Test loss: 1.163, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 34
# Training loss: 1.147, Training accuracy: 65.000
# Test loss: 1.147, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 35
# Training loss: 1.130, Training accuracy: 65.000
# Test loss: 1.130, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 36
# Training loss: 1.113, Training accuracy: 65.000
# Test loss: 1.113, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 37
# Training loss: 1.097, Training accuracy: 65.000
# Test loss: 1.097, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 38
# Training loss: 1.081, Training accuracy: 65.833
# Test loss: 1.081, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 39
# Training loss: 1.066, Training accuracy: 66.667
# Test loss: 1.066, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 40
# Training loss: 1.049, Training accuracy: 69.167
# Test loss: 1.049, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 41
# Training loss: 1.033, Training accuracy: 70.000
# Test loss: 1.033, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 42
# Training loss: 1.016, Training accuracy: 70.000
# Test loss: 1.016, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 43
# Training loss: 0.999, Training accuracy: 70.833
# Test loss: 0.999, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 44
# Training loss: 0.984, Training accuracy: 70.833
# Test loss: 0.984, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 45
# Training loss: 0.968, Training accuracy: 70.833
# Test loss: 0.968, Test accuracy: 73.333
# Training process has finished.
# Starting epoch 46
# Training loss: 0.953, Training accuracy: 73.333
# Test loss: 0.953, Test accuracy: 76.667
# Training process has finished.
# Starting epoch 47
# Training loss: 0.938, Training accuracy: 73.333
# Test loss: 0.938, Test accuracy: 76.667
# Training process has finished.
# Starting epoch 48
# Training loss: 0.924, Training accuracy: 74.167
# Test loss: 0.924, Test accuracy: 76.667
# Training process has finished.
# Starting epoch 49
# Training loss: 0.910, Training accuracy: 75.000
# Test loss: 0.910, Test accuracy: 76.667
# Training process has finished.
# Starting epoch 50
# Training loss: 0.897, Training accuracy: 75.000
# Test loss: 0.897, Test accuracy: 76.667
# Training process has finished.
# Starting epoch 51
# Training loss: 0.883, Training accuracy: 75.833
# Test loss: 0.883, Test accuracy: 80.000
# Training process has finished.
# Starting epoch 52
# Training loss: 0.870, Training accuracy: 76.667
# Test loss: 0.870, Test accuracy: 80.000
# Training process has finished.
# Starting epoch 53
# Training loss: 0.858, Training accuracy: 77.500
# Test loss: 0.858, Test accuracy: 80.000
# Training process has finished.
# Starting epoch 54
# Training loss: 0.846, Training accuracy: 78.333
# Test loss: 0.846, Test accuracy: 83.333
# Training process has finished.
# Starting epoch 55
# Training loss: 0.834, Training accuracy: 78.333
# Test loss: 0.834, Test accuracy: 83.333
# Training process has finished.
# Starting epoch 56
# Training loss: 0.822, Training accuracy: 78.333
# Test loss: 0.822, Test accuracy: 86.667
# Training process has finished.
# Starting epoch 57
# Training loss: 0.811, Training accuracy: 80.000
# Test loss: 0.811, Test accuracy: 86.667
# Training process has finished.
# Starting epoch 58
# Training loss: 0.800, Training accuracy: 80.000
# Test loss: 0.800, Test accuracy: 86.667
# Training process has finished.
# Starting epoch 59
# Training loss: 0.789, Training accuracy: 80.000
# Test loss: 0.789, Test accuracy: 86.667
# Training process has finished.
# Starting epoch 60
# Training loss: 0.779, Training accuracy: 80.833
# Test loss: 0.779, Test accuracy: 86.667
# Training process has finished.
# Starting epoch 61
# Training loss: 0.768, Training accuracy: 82.500
# Test loss: 0.768, Test accuracy: 86.667
# Training process has finished.
# Starting epoch 62
# Training loss: 0.758, Training accuracy: 84.167
# Test loss: 0.758, Test accuracy: 86.667
# Training process has finished.
# Starting epoch 63
# Training loss: 0.749, Training accuracy: 84.167
# Test loss: 0.749, Test accuracy: 86.667
# Training process has finished.
# Starting epoch 64
# Training loss: 0.739, Training accuracy: 83.333
# Test loss: 0.739, Test accuracy: 86.667
# Training process has finished.
# Starting epoch 65
# Training loss: 0.730, Training accuracy: 82.500
# Test loss: 0.730, Test accuracy: 86.667
# Training process has finished.
# Starting epoch 66
# Training loss: 0.721, Training accuracy: 82.500
# Test loss: 0.721, Test accuracy: 86.667
# Training process has finished.
# Starting epoch 67
# Training loss: 0.712, Training accuracy: 82.500
# Test loss: 0.712, Test accuracy: 86.667
# Training process has finished.
# Starting epoch 68
# Training loss: 0.704, Training accuracy: 83.333
# Test loss: 0.704, Test accuracy: 86.667
# Training process has finished.
# Starting epoch 69
# Training loss: 0.696, Training accuracy: 83.333
# Test loss: 0.696, Test accuracy: 86.667
# Training process has finished.
# Starting epoch 70
# Training loss: 0.688, Training accuracy: 83.333
# Test loss: 0.688, Test accuracy: 86.667
# Training process has finished.
# Starting epoch 71
# Training loss: 0.680, Training accuracy: 83.333
# Test loss: 0.680, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 72
# Training loss: 0.672, Training accuracy: 83.333
# Test loss: 0.672, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 73
# Training loss: 0.665, Training accuracy: 83.333
# Test loss: 0.665, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 74
# Training loss: 0.657, Training accuracy: 83.333
# Test loss: 0.657, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 75
# Training loss: 0.650, Training accuracy: 83.333
# Test loss: 0.650, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 76
# Training loss: 0.643, Training accuracy: 83.333
# Test loss: 0.643, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 77
# Training loss: 0.636, Training accuracy: 84.167
# Test loss: 0.636, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 78
# Training loss: 0.630, Training accuracy: 84.167
# Test loss: 0.630, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 79
# Training loss: 0.623, Training accuracy: 84.167
# Test loss: 0.623, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 80
# Training loss: 0.617, Training accuracy: 84.167
# Test loss: 0.617, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 81
# Training loss: 0.611, Training accuracy: 84.167
# Test loss: 0.611, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 82
# Training loss: 0.605, Training accuracy: 84.167
# Test loss: 0.605, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 83
# Training loss: 0.599, Training accuracy: 84.167
# Test loss: 0.599, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 84
# Training loss: 0.594, Training accuracy: 85.000
# Test loss: 0.594, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 85
# Training loss: 0.588, Training accuracy: 85.000
# Test loss: 0.588, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 86
# Training loss: 0.583, Training accuracy: 85.000
# Test loss: 0.583, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 87
# Training loss: 0.578, Training accuracy: 85.000
# Test loss: 0.578, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 88
# Training loss: 0.572, Training accuracy: 85.833
# Test loss: 0.572, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 89
# Training loss: 0.567, Training accuracy: 85.833
# Test loss: 0.567, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 90
# Training loss: 0.562, Training accuracy: 86.667
# Test loss: 0.562, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 91
# Training loss: 0.558, Training accuracy: 86.667
# Test loss: 0.558, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 92
# Training loss: 0.553, Training accuracy: 87.500
# Test loss: 0.553, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 93
# Training loss: 0.548, Training accuracy: 88.333
# Test loss: 0.548, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 94
# Training loss: 0.544, Training accuracy: 88.333
# Test loss: 0.544, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 95
# Training loss: 0.540, Training accuracy: 88.333
# Test loss: 0.540, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 96
# Training loss: 0.535, Training accuracy: 88.333
# Test loss: 0.535, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 97
# Training loss: 0.531, Training accuracy: 88.333
# Test loss: 0.531, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 98
# Training loss: 0.527, Training accuracy: 89.167
# Test loss: 0.527, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 99
# Training loss: 0.523, Training accuracy: 89.167
# Test loss: 0.523, Test accuracy: 90.000
# Training process has finished.
# Starting epoch 100
# Training loss: 0.519, Training accuracy: 89.167
# Test loss: 0.519, Test accuracy: 90.000
# Training process has finished.

# %% [markdown]
# ### Plot Accuracy and Loss

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)

ax1.plot(acc_list)
ax1.set_ylabel("training accuracy")
ax2.plot(loss_list)
ax2.set_ylabel("loss")
ax2.set_xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')
